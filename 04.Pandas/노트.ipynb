# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.read_csv('data/stocks_2016.csv')
pd.read_csv('data/stocks_2017.csv')
pd.read_csv('data/stocks_2018.csv')
pd.read_csv('data/stocks_info.csv')
# Out:
#   Symbol                                     Name
# 0   AAPL                                Apple Inc
# 1   TSLA                                Tesla Inc
# 2    WMT                              Walmart Inc
# 3     GE                         General Electric
# 4    IBM  IBM(International Business Machines Co)
# 5    SLB                    Schlumberger Limited.
# 6    TXN           Texas Instruments Incorporated
# 7   AMZN                          Amazon.com, Inc

# %%
file_names = ["2016","2017","2018","info"]
stock_2016, stock_2017, stock_2018,stock_info=[pd.read_csv(f'data/stocks_{name}.csv') for name in file_names]

# %%
result = pd.concat([stock_2016,stock_2017,stock_2018], keys=[
    '2016',  '2017', '2018'
])

# %%
result
# Out:
#        Symbol  Shares  Low  High
# 2016 0   AAPL      80   95   110
#      1   TSLA      50   80   130
#      2    WMT      40   55    70
# 2017 0   AAPL      50  120   140
#      1     GE     100   30    40
#      2    IBM      87   75    95
#      3    SLB      20   55    85
#      4    TXN     500   15    23
#      5   TSLA     100  100   300
# 2018 0   AAPL      40  135   170
#      1   AMZN       8  900  1125
#      2   TSLA      50  220   400

# %%
result.loc['2016',1]
# Out:
# Symbol    TSLA
# Shares      50
# Low         80
# High       130
# Name: (2016, 1), dtype: object

# %%
stock_2016.set_index('Symbol').join(stock_2018.set_index('Symbol'), lsuffix = '_2016',
rsuffix='_2018', how = 'right')
# Out:
#         Shares_2016  Low_2016  High_2016  Shares_2018  Low_2018  High_2018
# Symbol
# AAPL           80.0      95.0      110.0           40       135        170
# AMZN            NaN       NaN        NaN            8       900       1125
# TSLA           50.0      80.0      130.0           50       220        400

# %%
stock_info.set_index('Symbol').join([])
# Out:
#                                            Name
# Symbol
# AAPL                                  Apple Inc
# TSLA                                  Tesla Inc
# WMT                                 Walmart Inc
# GE                             General Electric
# IBM     IBM(International Business Machines Co)
# SLB                       Schlumberger Limited.
# TXN              Texas Instruments Incorporated
# AMZN                            Amazon.com, Inc

# %%
stock_info.join(stock_2016)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 stock_info.join(stock_2016)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9729, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9566 def join(
#    9567     self,
#    9568     other: DataFrame | Series | Iterable[DataFrame | Series],
#    (...)
#    9574     validate: str | None = None,
#    9575 ) -> DataFrame:
#    9576     """
#    9577     Join columns of another DataFrame.
#    9578
#    (...)
#    9727     5  K1  A5   B1
#    9728     """
# -> 9729     return self._join_compat(
#    9730         other,
#    9731         on=on,
#    9732         how=how,
#    9733         lsuffix=lsuffix,
#    9734         rsuffix=rsuffix,
#    9735         sort=sort,
#    9736         validate=validate,
#    9737     )
#
# ...

# %%
stock_2016_2 = stock_2016.set_index('Symbol')
stock_2016_2
# Out:
#         Shares  Low  High
# Symbol
# AAPL        80   95   110
# TSLA        50   80   130
# WMT         40   55    70

# %%
stock_2016_2 = stock_2016.set_index("Symbol").add_suffix("_2016")
stock_2017_2 = stock_2017.set_index("Symbol").add_suffix("_2017")

# %%
stock_info
# Out:
#   Symbol                                     Name
# 0   AAPL                                Apple Inc
# 1   TSLA                                Tesla Inc
# 2    WMT                              Walmart Inc
# 3     GE                         General Electric
# 4    IBM  IBM(International Business Machines Co)
# 5    SLB                    Schlumberger Limited.
# 6    TXN           Texas Instruments Incorporated
# 7   AMZN                          Amazon.com, Inc

# %%
stock_2018
# Out:
#   Symbol  Shares  Low  High
# 0   AAPL      40  135   170
# 1   AMZN       8  900  1125
# 2   TSLA      50  220   400

# %%
stock_2016
# Out:
#   Symbol  Shares  Low  High
# 0   AAPL      80   95   110
# 1   TSLA      50   80   130
# 2    WMT      40   55    70

# %%
stock_info
# Out:
#   Symbol                                     Name
# 0   AAPL                                Apple Inc
# 1   TSLA                                Tesla Inc
# 2    WMT                              Walmart Inc
# 3     GE                         General Electric
# 4    IBM  IBM(International Business Machines Co)
# 5    SLB                    Schlumberger Limited.
# 6    TXN           Texas Instruments Incorporated
# 7   AMZN                          Amazon.com, Inc

# %%
stock_info.merge(stock_2016, left_index = True, right_on ='Symbol')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[124], line 1
# ----> 1 stock_info.merge(stock_2016, left_index = True, right_on ='Symbol')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9843, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9824 @Substitution("")
#    9825 @Appender(_merge_doc, indents=2)
#    9826 def merge(
#    (...)
#    9839     validate: str | None = None,
#    9840 ) -> DataFrame:
#    9841     from pandas.core.reshape.merge import merge
# -> 9843     return merge(
#    9844         self,
#    9845         right,
#    9846         how=how,
#    9847         on=on,
#    9848         left_on=left_on,
#    9849         right_on=right_on,
#    9850         left_index=left_index,
#    9851         right_index=right_index,
#    9852         sort=sort,
# ...

# %%
stock_2016
# Out:
#   Symbol  Shares  Low  High
# 0   AAPL      80   95   110
# 1   TSLA      50   80   130
# 2    WMT      40   55    70

# %%
stock_info
# Out:
#   Symbol                                     Name
# 0   AAPL                                Apple Inc
# 1   TSLA                                Tesla Inc
# 2    WMT                              Walmart Inc
# 3     GE                         General Electric
# 4    IBM  IBM(International Business Machines Co)
# 5    SLB                    Schlumberger Limited.
# 6    TXN           Texas Instruments Incorporated
# 7   AMZN                          Amazon.com, Inc

# %%
stock_2018_2
# Out:
#         Shares_2017  Low_2017  High_2017
# Symbol
# AAPL             50       120        140
# GE              100        30         40
# IBM              87        75         95
# SLB              20        55         85
# TXN             500        15         23
# TSLA            100       100        300

# %%
 stock_2018_2.merge(stock_info, left_index=True,right_on='Symbol')
# Out:
#    Shares_2017  Low_2017  High_2017 Symbol  \
# 0           50       120        140   AAPL
# 3          100        30         40     GE
# 4           87        75         95    IBM
# 5           20        55         85    SLB
# 6          500        15         23    TXN
# 1          100       100        300   TSLA
#
#                                       Name
# 0                                Apple Inc
# 3                         General Electric
# 4  IBM(International Business Machines Co)
# 5                    Schlumberger Limited.
# 6           Texas Instruments Incorporated
# 1                                Tesla Inc
