# %% [markdown]
# kgmyh@naver.com 으로 `이름_주유소가격 데이터 분석.html` 로 제출
# - html 파일로 변환
#     - File > Download as > HTML (.html) 선택
#     - File > Save and Export Notebook As .. > HTML 선택

# %% [markdown]
# # 데이터 불러오기

# %% [markdown]
# - 2022년 주유소들의 일자별 가격 데이터
# - https://www.opinet.co.kr/user/opdown/opDownload.do

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/2022년_서울_상반기_일별_가격.csv', encoding='cp949')
df
# Out:
#              번호      지역                  상호                    주소        기간  \
# 0      A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220101
# 1      A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220102
# 2      A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220103
# 3      A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220104
# 4      A0006039  서울 강남구     (유)동하석유 힐탑셀프주유소        서울 강남구 논현로 640  20220105
# ...         ...     ...                 ...                   ...       ...
# 82684  A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220507
# 82685  A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220508
# 82686  A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220509
# 82687  A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220510
# 82688  A0009197  서울 중랑구  현대오일뱅크㈜직영 중랑교셀프주유소  서울 중랑구 망우로 229 (중화동)  20220511
#
#            상표 셀프여부  고급휘발유   휘발유    경유  실내등유
# 0       SK에너지   셀프   1887  1737  1587     0
# 1       SK에너지   셀프   1887  1737  1587     0
# 2       SK에너지   셀프   1887  1737  1587     0
# 3       SK에너지   셀프   1887  1737  1587     0
# 4       SK에너지   셀프   1887  1737  1587     0
# ...       ...  ...    ...   ...   ...   ...
# 82684  현대오일뱅크   셀프   2152  1910  1841     0
# 82685  현대오일뱅크   셀프   2152  1910  1841     0
# 82686  현대오일뱅크   셀프   2152  1910  1841     0
# 82687  현대오일뱅크   셀프   2152  1910  1841     0
# 82688  현대오일뱅크   셀프   2152  1910  1841     0
#
# [82689 rows x 11 columns]

# %%
df2 = pd.read_csv('data/2022년_서울_하반기_일별_가격.csv', encoding = 'cp949')
df2
# Out:
#              번호      지역               상호                       주소        기간  \
# 0      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220701
# 1      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220702
# 2      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220703
# 3      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220704
# 4      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220705
# ...         ...     ...              ...                      ...       ...
# 81788  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221227
# 81789  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221228
# 81790  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221229
# 81791  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221230
# 81792  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221231
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유
# 0      SK에너지   셀프   2487  2287  2297     0
# 1      SK에너지   셀프   2447  2247  2277     0
# 2      SK에너지   셀프   2447  2247  2277     0
# 3      SK에너지   셀프   2447  2247  2277     0
# 4      SK에너지   셀프   2447  2247  2277     0
# ...      ...  ...    ...   ...   ...   ...
# 81788  GS칼텍스   셀프      0  1525  1745     0
# 81789  GS칼텍스   셀프      0  1525  1720     0
# 81790  GS칼텍스   셀프      0  1525  1720     0
# 81791  GS칼텍스   셀프      0  1515  1715     0
# 81792  GS칼텍스   셀프      0  1515  1715     0
#
# [81793 rows x 11 columns]

# %%
# 상반기, 하반기 주유소 가격 데이터 조회

# %%
df.filter(like='유') ,df.filter(like='유')
# Out:
# (       고급휘발유   휘발유    경유  실내등유
#  0       1887  1737  1587     0
#  1       1887  1737  1587     0
#  2       1887  1737  1587     0
#  3       1887  1737  1587     0
#  4       1887  1737  1587     0
#  ...      ...   ...   ...   ...
#  82684   2152  1910  1841     0
#  82685   2152  1910  1841     0
#  82686   2152  1910  1841     0
#  82687   2152  1910  1841     0
#  82688   2152  1910  1841     0
#
#  [82689 rows x 4 columns],
#         고급휘발유   휘발유    경유  실내등유
#  0       1887  1737  1587     0
#  1       1887  1737  1587     0
#  2       1887  1737  1587     0
#  3       1887  1737  1587     0
#  4       1887  1737  1587     0
#  ...      ...   ...   ...   ...
#  82684   2152  1910  1841     0
#  82685   2152  1910  1841     0
#  82686   2152  1910  1841     0
#  82687   2152  1910  1841     0
#  82688   2152  1910  1841     0
#
#  [82689 rows x 4 columns])

# %%
# 상반기, 하반기 DataFrame 합치기

# %%
result = pd.concat([df, df2])
result
# Out:
#              번호      지역               상호                       주소        기간  \
# 0      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220101
# 1      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220102
# 2      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220103
# 3      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220104
# 4      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220105
# ...         ...     ...              ...                      ...       ...
# 81788  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221227
# 81789  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221228
# 81790  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221229
# 81791  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221230
# 81792  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221231
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유
# 0      SK에너지   셀프   1887  1737  1587     0
# 1      SK에너지   셀프   1887  1737  1587     0
# 2      SK에너지   셀프   1887  1737  1587     0
# 3      SK에너지   셀프   1887  1737  1587     0
# 4      SK에너지   셀프   1887  1737  1587     0
# ...      ...  ...    ...   ...   ...   ...
# 81788  GS칼텍스   셀프      0  1525  1745     0
# 81789  GS칼텍스   셀프      0  1525  1720     0
# 81790  GS칼텍스   셀프      0  1525  1720     0
# 81791  GS칼텍스   셀프      0  1515  1715     0
# 81792  GS칼텍스   셀프      0  1515  1715     0
#
# [164482 rows x 11 columns]

# %%
# DataFrame 기본 정보 조회
result.info
# Out:
# <bound method DataFrame.info of              번호      지역               상호                       주소        기간  \
# 0      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220101
# 1      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220102
# 2      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220103
# 3      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220104
# 4      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220105
# ...         ...     ...              ...                      ...       ...
# 81788  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221227
# 81789  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221228
# 81790  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221229
# 81791  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221230
# 81792  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221231
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유
# 0      SK에너지   셀프   1887  1737  1587     0
# 1      SK에너지   셀프   1887  1737  1587     0
# 2      SK에너지   셀프   1887  1737  1587     0
# 3      SK에너지   셀프   1887  1737  1587     0
# 4      SK에너지   셀프   1887  1737  1587     0
# ...      ...  ...    ...   ...   ...   ...
# 81788  GS칼텍스   셀프      0  1525  1745     0
# 81789  GS칼텍스   셀프      0  1525  1720     0
# 81790  GS칼텍스   셀프      0  1525  1720     0
# 81791  GS칼텍스   셀프      0  1515  1715     0
# 81792  GS칼텍스   셀프      0  1515  1715     0
#
# [164482 rows x 11 columns]>

# %%
# 상표 컬럼의 고유값 조회
result[['상표']]
# Out:
#           상표
# 0      SK에너지
# 1      SK에너지
# 2      SK에너지
# 3      SK에너지
# 4      SK에너지
# ...      ...
# 81788  GS칼텍스
# 81789  GS칼텍스
# 81790  GS칼텍스
# 81791  GS칼텍스
# 81792  GS칼텍스
#
# [164482 rows x 1 columns]

# %%
# 지역 컬럼의 고유값 조회
result[['지역']]
# Out:
#            지역
# 0      서울 강남구
# 1      서울 강남구
# 2      서울 강남구
# 3      서울 강남구
# 4      서울 강남구
# ...       ...
# 81788  서울 중랑구
# 81789  서울 중랑구
# 81790  서울 중랑구
# 81791  서울 중랑구
# 81792  서울 중랑구
#
# [164482 rows x 1 columns]

# %% [markdown]
# > ### str accessor
# > - `Series.str.String메소드()`
# > - 문자열 타입 Series에 String 메소드들을 사용하여 일괄처리 할 수 있도록 한다.
# > - str accessor 메소드 : https://pandas.pydata.org/pandas-docs/stable/reference/series.html#api-series-str
#
# > ### datetime으로 변환
# > - `pd.to_datetime(변환할 Series, format="날짜형식")`
# > - x 또는 y 축이 날짜 일 경우 datetime 타입으로 처리하는 것이 좋다.
# > - format: 년월일의 형식을 strftime 형식문자열로 지정한다.
# >      - [strftime 형식](https://docs.python.org/3/library/datetime.html#strftime-and-strptime-format-codes)
# > - datetime을 변환하면 날짜만의 기능을 다룰 수 있다.
# >     - dt accessor를 이용해 datetime의 속성값들을(년, 월, 일 등) 추출할 수 있다.
# >     - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html

# %%
# 지역 컬럼의 값을 이용하여 "구" 컬럼 생성 (지역에서 구만 추출해서 파생변수컬럼 생성)
result.filter
# Out:
#              번호      지역               상호                       주소        기간  \
# 0      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220101
# 1      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220102
# 2      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220103
# 3      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220104
# 4      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220105
# ...         ...     ...              ...                      ...       ...
# 81788  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221227
# 81789  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221228
# 81790  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221229
# 81791  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221230
# 81792  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221231
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유         구
# 0      SK에너지   셀프   1887  1737  1587     0  10101010
# 1      SK에너지   셀프   1887  1737  1587     0  10101010
# 2      SK에너지   셀프   1887  1737  1587     0  10101010
# 3      SK에너지   셀프   1887  1737  1587     0  10101010
# 4      SK에너지   셀프   1887  1737  1587     0  10101010
# ...      ...  ...    ...   ...   ...   ...       ...
# 81788  GS칼텍스   셀프      0  1525  1745     0  10101010
# 81789  GS칼텍스   셀프      0  1525  1720     0  10101010
# 81790  GS칼텍스   셀프      0  1525  1720     0  10101010
# 81791  GS칼텍스   셀프      0  1515  1715     0  10101010
# 81792  GS칼텍스   셀프      0  1515  1715     0  10101010
#
# [164482 rows x 12 columns]

# %%
# 기간 컬럼을 datetime 타입으로 변경
pd.to_datetime(result['기간'])
# Out:
# 0       1970-01-01 00:00:00.020220101
# 1       1970-01-01 00:00:00.020220102
# 2       1970-01-01 00:00:00.020220103
# 3       1970-01-01 00:00:00.020220104
# 4       1970-01-01 00:00:00.020220105
#                      ...
# 81788   1970-01-01 00:00:00.020221227
# 81789   1970-01-01 00:00:00.020221228
# 81790   1970-01-01 00:00:00.020221229
# 81791   1970-01-01 00:00:00.020221230
# 81792   1970-01-01 00:00:00.020221231
# Name: 기간, Length: 164482, dtype: datetime64[ns]

# %%
# 기간 컬럼을 이용해 "월", "일", "요일" 컬럼 생성 (dt accessor 이용)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/tslibs/strptime.pyx:244, in pandas._libs.tslibs.strptime.array_strptime()
#
# File ~/anaconda3/lib/python3.11/_strptime.py:263, in TimeRE.compile(self, format)
#     262 """Return a compiled re object for the format string."""
# --> 263 return re_compile(self.pattern(format), IGNORECASE)
#
# File ~/anaconda3/lib/python3.11/_strptime.py:257, in TimeRE.pattern(self, format)
#     254 directive_index = format.index('%')+1
#     255 processed_format = "%s%s%s" % (processed_format,
#     256                                format[:directive_index-1],
# --> 257                                self[format[directive_index]])
#     258 format = format[directive_index+1:]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/tslibs/strptime.pyx:565, in pandas._libs.tslibs.strptime.TimeRE.__getitem__()
#
# KeyError: '년'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 2
#       1 # 기간 컬럼을 이용해 "월", "일", "요일" 컬럼 생성 (dt accessor 이용)
# ----> 2 pd.to_datetime(result['기간'], format='Y%년')
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:1046, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1044             result = arg.tz_localize("utc")
#    1045 elif isinstance(arg, ABCSeries):
# -> 1046     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1047     if not cache_array.empty:
#    1048         result = arg.map(cache_array)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:250, in _maybe_cache(arg, format, cache, convert_listlike)
#     248 unique_dates = unique(arg)
#     249 if len(unique_dates) < len(arg):
# --> 250     cache_dates = convert_listlike(unique_dates, format)
#     251     # GH#45319
#     252     try:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452 if format is not None and format != "mixed":
# --> 453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     455 result, tz_parsed = objects_to_datetime64ns(
#     456     arg,
#     457     dayfirst=dayfirst,
#    (...)
#     461     allow_object=True,
#     462 )
#     464 if tz_parsed is not None:
#     465     # We can take a shortcut since the datetime64 numpy array
#     466     # is in UTC
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/tools/datetimes.py:484, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     473 def _array_strptime_with_fallback(
#     474     arg,
#     475     name,
#    (...)
#     479     errors: str,
#     480 ) -> Index:
#     481     """
#     482     Call array_strptime, with fallback behavior depending on 'errors'.
#     483     """
# --> 484     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     485     if any(tz is not None for tz in timezones):
#     486         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/tslibs/strptime.pyx:234, in pandas._libs.tslibs.strptime.array_strptime()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/tslibs/strptime.pyx:252, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: '년' is a bad directive in format 'Y%년'

# %%
# 요일 - 0:월, 1:화, 2:수, 3:목, 4:금, 5:토, 6:일 로 변경

# %%
# 휘발유 가격이 가장 비싼 5개 행 조회
result.sort_values('휘발유', ascending= False).head()
# Out:
#              번호     지역     상호            주소        기간     상표 셀프여부  고급휘발유  \
# 78935  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220622  SK에너지   일반   3496
# 78939  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220626  SK에너지   일반   3496
# 78937  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220624  SK에너지   일반   3496
# 78936  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220623  SK에너지   일반   3496
# 78940  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220627  SK에너지   일반   3496
#
#         휘발유    경유  실내등유         구
# 78935  3096  3223  2719  10101010
# 78939  3096  3223  2719  10101010
# 78937  3096  3223  2719  10101010
# 78936  3096  3223  2719  10101010
# 78940  3096  3223  2719  10101010

# %%
# 휘발유 가격이 가장 저렴한 5개 행 조회 (단 0원인 주유소 제외)
result[result['휘발유']>0].sort_values('휘발유').head()
# Out:
#              번호      지역               상호                      주소        기간  \
# 16809  A0000519  서울 강서구           화곡역주유소    서울 강서구 강서로 154 (화곡동)  20221227
# 15150  A0000549  서울 강서구  이케이에너지(주) 강서주유소    서울 강서구 화곡로 273 (화곡동)  20221224
# 15151  A0000549  서울 강서구  이케이에너지(주) 강서주유소    서울 강서구 화곡로 273 (화곡동)  20221225
# 65744  A0001005  서울 양천구            현대주유소  서울 양천구 남부순환로 372 (신월동)  20221226
# 15149  A0000549  서울 강서구  이케이에너지(주) 강서주유소    서울 강서구 화곡로 273 (화곡동)  20221223
#
#            상표 셀프여부  고급휘발유   휘발유    경유  실내등유         구
# 16809   알뜰주유소   셀프      0  1410  1660     0  10101010
# 15150  현대오일뱅크   셀프      0  1410  1660     0  10101010
# 15151  현대오일뱅크   셀프      0  1410  1660     0  10101010
# 65744   S-OIL   셀프      0  1410  1660     0  10101010
# 15149  현대오일뱅크   셀프      0  1410  1660     0  10101010

# %%
# 고급휘발유 가격이 가장 비싼 5개 행 조회
result.sort_values('고급휘발유', ascending= False).head()
# Out:
#              번호     지역     상호            주소        기간     상표 셀프여부  고급휘발유  \
# 78940  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220627  SK에너지   일반   3496
# 78939  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220626  SK에너지   일반   3496
# 78938  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220625  SK에너지   일반   3496
# 78937  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220624  SK에너지   일반   3496
# 78936  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220623  SK에너지   일반   3496
#
#         휘발유    경유  실내등유         구
# 78940  3096  3223  2719  10101010
# 78939  3096  3223  2719  10101010
# 78938  3096  3223  2719  10101010
# 78937  3096  3223  2719  10101010
# 78936  3096  3223  2719  10101010

# %%
# 고급휘발유 가격이 가장 저렴한 5개 행 조회 (단 0원인 주유소 제외)
result[result['고급휘발유']>0].sort_values('고급휘발유').head()
# Out:
#              번호      지역       상호                       주소        기간     상표  \
# 15882  A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동)  20221220  S-OIL
# 15883  A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동)  20221221  S-OIL
# 15884  A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동)  20221222  S-OIL
# 15885  A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동)  20221223  S-OIL
# 15886  A0000520  서울 강서구  하이웨이주유소  서울특별시 강서구 공항대로 432(화곡동)  20221224  S-OIL
#
#       셀프여부  고급휘발유   휘발유    경유  실내등유         구
# 15882   셀프   1599  1527  1787     0  10101010
# 15883   셀프   1599  1499  1759     0  10101010
# 15884   셀프   1599  1499  1759     0  10101010
# 15885   셀프   1599  1499  1729     0  10101010
# 15886   셀프   1599  1499  1729     0  10101010

# %%
# 경유 가격이 가장 비싼 5개 행 조회
result.sort_values('경유', ascending=False).head()
# Out:
#              번호     지역     상호            주소        기간     상표 셀프여부  고급휘발유  \
# 78942  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220629  SK에너지   일반   3481
# 77929  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220701  SK에너지   일반   3481
# 78941  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220628  SK에너지   일반   3481
# 78943  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220630  SK에너지   일반   3481
# 77932  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220704  SK에너지   일반   3481
#
#         휘발유    경유  실내등유         구
# 78942  3081  3230  2703  10101010
# 77929  3081  3230  2703  10101010
# 78941  3081  3230  2703  10101010
# 78943  3081  3230  2703  10101010
# 77932  3081  3230  2703  10101010

# %%
# 경유 가격이 가장 저렴한 5개 행 조회 (단 0원인 주유소 제외)
result[result['경유']>0].sort_values('경유', ascending=False).head()
# Out:
#              번호     지역     상호            주소        기간     상표 셀프여부  고급휘발유  \
# 77930  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220702  SK에너지   일반   3481
# 78941  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220628  SK에너지   일반   3481
# 77931  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220703  SK에너지   일반   3481
# 77932  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220704  SK에너지   일반   3481
# 77929  A0000767  서울 중구  서남주유소  서울 중구 통일로 30  20220701  SK에너지   일반   3481
#
#         휘발유    경유  실내등유         구
# 77930  3081  3230  2703  10101010
# 78941  3081  3230  2703  10101010
# 77931  3081  3230  2703  10101010
# 77932  3081  3230  2703  10101010
# 77929  3081  3230  2703  10101010

# %%
# 상표별 휘발유 평균가격 조회
k = result.pivot_table(index = '상표',
                  values = '휘발유',
                  aggfunc= 'mean')
k
# Out:
#                 휘발유
# 상표
# GS칼텍스   1904.899429
# S-OIL   1859.282595
# SK에너지   1908.900823
# 알뜰(ex)  1759.884932
# 알뜰주유소   1767.914672
# 자가상표    1823.622795
# 현대오일뱅크  1839.447215

# %%
# 상표별 휘발유 평균가격 시각화
# Out:
#              번호      지역               상호                       주소        기간  \
# 0      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220101
# 1      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220102
# 2      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220103
# 3      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220104
# 4      A0006039  서울 강남구  (유)동하석유 힐탑셀프주유소           서울 강남구 논현로 640  20220105
# ...         ...     ...              ...                      ...       ...
# 81788  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221227
# 81789  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221228
# 81790  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221229
# 81791  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221230
# 81792  A0009138  서울 중랑구            우림주유소  서울 중랑구 용마산로 487 (망우제3동)  20221231
#
#           상표 셀프여부  고급휘발유   휘발유    경유  실내등유  휘발유평균가격
# 0      SK에너지   셀프   1887  1737  1587     0      NaN
# 1      SK에너지   셀프   1887  1737  1587     0      NaN
# 2      SK에너지   셀프   1887  1737  1587     0      NaN
# 3      SK에너지   셀프   1887  1737  1587     0      NaN
# 4      SK에너지   셀프   1887  1737  1587     0      NaN
# ...      ...  ...    ...   ...   ...   ...      ...
# 81788  GS칼텍스   셀프      0  1525  1745     0      NaN
# 81789  GS칼텍스   셀프      0  1525  1720     0      NaN
# 81790  GS칼텍스   셀프      0  1525  1720     0      NaN
# 81791  GS칼텍스   셀프      0  1515  1715     0      NaN
# 81792  GS칼텍스   셀프      0  1515  1715     0      NaN
#
# [164482 rows x 12 columns]

# %%
# 셀프주유소와 일반주유소 개수 확인

# %%
# 셀프 여부에 따른 휘발유 평균 가격 비교

# %%
# 상표별 일반/셀프 주유소의 휘발유 가격 평균 비교

# %%
# 상표별 일반/셀프 주유소의 휘발유 가격 평균 비교 시각화

# %%
# 상표별 휘발유 가격의 분포를 boxplot으로 시각화

# %%
# 상표별 일반/셀프 주유소의 휘발유 가격에 대한 분포 확인 - boxplot으로 시각화

# %%
# 구별 휘발유 가격의 평균

# %%
# 평균 가격이 가장 높은 구의 상표별 휘발유 평균가격

# %%
# 월 평균 휘발유 가격

# %%
# 각 구의 월별 평균 휘발유 가격

# %%
# 각 구의 월별 평균가격의 변화추이 시각화

# %%
# 가장 휘발유가격이 비싼 주유소 상위 5 - (같은 주유소가 여러개 나오므로 가장 비싼 가격을 기준으로 집계)

# %%
# 가장 휘발유가격이 저렴한 주유소 상위 5 - (같은 주유소가 여러개 나오므로 가장 비싼 가격을 기준으로 집계)

# %%
# 휘발유 비싼 주유소의 상위 5개의 상호, 주소, 상표, 셀프여부,  조회 - 위에서 조회한 결과에 추가 정보(상표, 셀프여부 등) 조회 (중복제거-drop_duplicates)

# %%
# 휘발유 저렴한 주유소의 상위 5개의 상호, 주소, 상표, 셀프여부,  조회 - 위에서 조회한 결과에 추가 정보(상표, 셀프여부 등) 조회 (중복제거-drop_duplicates)

# %%
# 고급 휘발유를 가장 많이 파는 구 조회

# %%
###############################################################################
# 주유소 가격 데이터를 이용해서 알고 싶은 정보들을 추가 분석해 보세요.
###############################################################################
